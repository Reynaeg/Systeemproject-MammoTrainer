# %%
#run this if you need to instale gradio still otherwise keep it like this
#!pip install --upgrade gradio
# Out:
# Collecting gradio
#   Downloading gradio-6.15.2-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\mfrat\anaconda3\lib\site-packages (from gradio) (4.2.0)
# Collecting brotli>=1.1.0 (from gradio)
#   Downloading brotli-1.2.0-cp312-cp312-win_amd64.whl.metadata (6.3 kB)
# Collecting fastapi<1.0,>=0.115.2 (from gradio)
#   Downloading fastapi-0.136.3-py3-none-any.whl.metadata (27 kB)
# Collecting gradio-client==2.5.0 (from gradio)
#   Downloading gradio_client-2.5.0-py3-none-any.whl.metadata (7.1 kB)
# Collecting groovy~=0.1 (from gradio)
#   Downloading groovy-0.1.2-py3-none-any.whl.metadata (6.1 kB)
# Collecting hf-gradio<1.0,>=0.4.1 (from gradio)
#   Downloading hf_gradio-0.4.1-py3-none-any.whl.metadata (428 bytes)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in c:\users\mfrat\anaconda3\lib\site-packages (from gradio) (0.27.0)
# Collecting huggingface-hub<2.0,>=0.33.5 (from gradio)
#   Downloading huggingface_hub-1.17.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: jinja2<4.0 in c:\users\mfrat\anaconda3\lib\site-packages (from gradio) (3.1.4)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in c:\users\mfrat\anaconda3\lib\site-packages (from gradio) (2.1.3)
# Requirement already satisfied: numpy<3.0,>=1.0 in c:\users\mfrat\anaconda3\lib\site-packages (from gradio) (1.26.4)
# Collecting orjson~=3.0 (from gradio)
#   Downloading orjson-3.11.9-cp312-cp312-win_amd64.whl.metadata (43 kB)
# Requirement already satisfied: packaging in c:\users\mfrat\anaconda3\lib\site-packages (from gradio) (25.0)
# Requirement already satisfied: pandas<4.0,>=1.0 in c:\users\mfrat\anaconda3\lib\site-packages (from gradio) (2.2.3)
# Requirement already satisfied: pillow<13.0,>=8.0 in c:\users\mfrat\anaconda3\lib\site-packages (from gradio) (10.4.0)
# Requirement already satisfied: pydantic<=3.0,>=2.0 in c:\users\mfrat\anaconda3\lib\site-packages (from gradio) (2.8.2)
# Collecting pydub<1.0 (from gradio)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting python-multipart<1.0,>=0.0.18 (from gradio)
#   Downloading python_multipart-0.0.30-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: pytz>=2017.2 in c:\users\mfrat\anaconda3\lib\site-packages (from gradio) (2024.2)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\mfrat\anaconda3\lib\site-packages (from gradio) (6.0.1)
# Collecting safehttpx<0.2.0,>=0.1.7 (from gradio)
#   Downloading safehttpx-0.1.7-py3-none-any.whl.metadata (4.2 kB)
# Collecting semantic-version~=2.0 (from gradio)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting starlette<2.0,>=1.0.1 (from gradio)
#   Downloading starlette-1.2.1-py3-none-any.whl.metadata (6.3 kB)
# Collecting tomlkit<0.15.0,>=0.12.0 (from gradio)
#   Downloading tomlkit-0.14.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting typer<1.0,>=0.12 (from gradio)
#   Downloading typer-0.26.4-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\mfrat\anaconda3\lib\site-packages (from gradio) (4.11.0)
# Collecting uvicorn>=0.14.0 (from gradio)
#   Downloading uvicorn-0.48.0-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: fsspec in c:\users\mfrat\anaconda3\lib\site-packages (from gradio-client==2.5.0->gradio) (2024.6.1)
# Requirement already satisfied: idna>=2.8 in c:\users\mfrat\anaconda3\lib\site-packages (from anyio<5.0,>=3.0->gradio) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\mfrat\anaconda3\lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.3.0)
# Collecting pydantic<=3.0,>=2.0 (from gradio)
#   Downloading pydantic-2.13.4-py3-none-any.whl.metadata (109 kB)
# Collecting typing-inspection>=0.4.2 (from fastapi<1.0,>=0.115.2->gradio)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting annotated-doc>=0.0.2 (from fastapi<1.0,>=0.115.2->gradio)
#   Downloading annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: certifi in c:\users\mfrat\anaconda3\lib\site-packages (from httpx<1.0,>=0.24.1->gradio) (2025.6.15)
# Requirement already satisfied: httpcore==1.* in c:\users\mfrat\anaconda3\lib\site-packages (from httpx<1.0,>=0.24.1->gradio) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\mfrat\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio) (0.14.0)
# Collecting click>=8.4.0 (from huggingface-hub<2.0,>=0.33.5->gradio)
#   Downloading click-8.4.1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: filelock>=3.10.0 in c:\users\mfrat\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (3.13.1)
# Collecting hf-xet<2.0.0,>=1.4.3 (from huggingface-hub<2.0,>=0.33.5->gradio)
#   Downloading hf_xet-1.5.0-cp37-abi3-win_amd64.whl.metadata (4.9 kB)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\mfrat\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (4.67.1)
# Collecting typer<1.0,>=0.12 (from gradio)
#   Downloading typer-0.25.1-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\mfrat\anaconda3\lib\site-packages (from pandas<4.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\mfrat\anaconda3\lib\site-packages (from pandas<4.0,>=1.0->gradio) (2023.3)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\mfrat\anaconda3\lib\site-packages (from pydantic<=3.0,>=2.0->gradio) (0.6.0)
# Collecting pydantic-core==2.46.4 (from pydantic<=3.0,>=2.0->gradio)
#   Downloading pydantic_core-2.46.4-cp312-cp312-win_amd64.whl.metadata (6.7 kB)
# Collecting typing-extensions~=4.0 (from gradio)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\mfrat\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (1.5.0)
# Requirement already satisfied: rich>=13.8.0 in c:\users\mfrat\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (13.9.4)
# Requirement already satisfied: colorama in c:\users\mfrat\anaconda3\lib\site-packages (from click>=8.4.0->huggingface-hub<2.0,>=0.33.5->gradio) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\mfrat\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas<4.0,>=1.0->gradio) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\mfrat\anaconda3\lib\site-packages (from rich>=13.8.0->typer<1.0,>=0.12->gradio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\mfrat\anaconda3\lib\site-packages (from rich>=13.8.0->typer<1.0,>=0.12->gradio) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\mfrat\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<1.0,>=0.12->gradio) (0.1.0)
# Downloading gradio-6.15.2-py3-none-any.whl (20.1 MB)
#    ---------------------------------------- 0.0/20.1 MB ? eta -:--:--
#    ---------------------------------------  19.9/20.1 MB 114.3 MB/s eta 0:00:01
#    ---------------------------------------- 20.1/20.1 MB 91.0 MB/s eta 0:00:00
# Downloading gradio_client-2.5.0-py3-none-any.whl (59 kB)
# Downloading brotli-1.2.0-cp312-cp312-win_amd64.whl (369 kB)
# Downloading fastapi-0.136.3-py3-none-any.whl (117 kB)
# Downloading groovy-0.1.2-py3-none-any.whl (14 kB)
# Downloading hf_gradio-0.4.1-py3-none-any.whl (4.5 kB)
# Downloading huggingface_hub-1.17.0-py3-none-any.whl (671 kB)
#    ---------------------------------------- 0.0/671.5 kB ? eta -:--:--
#    --------------------------------------- 671.5/671.5 kB 25.6 MB/s eta 0:00:00
# Downloading orjson-3.11.9-cp312-cp312-win_amd64.whl (127 kB)
# Downloading pydantic-2.13.4-py3-none-any.whl (472 kB)
# Downloading pydantic_core-2.46.4-cp312-cp312-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 2.1/2.1 MB 120.7 MB/s eta 0:00:00
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Downloading python_multipart-0.0.30-py3-none-any.whl (29 kB)
# Downloading safehttpx-0.1.7-py3-none-any.whl (9.0 kB)
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading starlette-1.2.1-py3-none-any.whl (73 kB)
# Downloading tomlkit-0.14.0-py3-none-any.whl (39 kB)
# Downloading typer-0.25.1-py3-none-any.whl (58 kB)
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading uvicorn-0.48.0-py3-none-any.whl (71 kB)
# Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Downloading click-8.4.1-py3-none-any.whl (116 kB)
# Downloading hf_xet-1.5.0-cp37-abi3-win_amd64.whl (4.0 MB)
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------------------- 4.0/4.0 MB 119.8 MB/s eta 0:00:00
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Installing collected packages: pydub, brotli, typing-extensions, tomlkit, semantic-version, python-multipart, orjson, hf-xet, groovy, click, annotated-doc, uvicorn, typing-inspection, starlette, pydantic-core, typer, safehttpx, pydantic, huggingface-hub, fastapi, gradio-client, hf-gradio, gradio
#   Attempting uninstall: brotli
#     Found existing installation: Brotli 1.0.9
#     Uninstalling Brotli-1.0.9:
#       Successfully uninstalled Brotli-1.0.9
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.11.0
#     Uninstalling typing_extensions-4.11.0:
#       Successfully uninstalled typing_extensions-4.11.0
#   Attempting uninstall: tomlkit
#     Found existing installation: tomlkit 0.11.1
#     Uninstalling tomlkit-0.11.1:
#       Successfully uninstalled tomlkit-0.11.1
#   Attempting uninstall: click
#     Found existing installation: click 8.1.7
#     Uninstalling click-8.1.7:
#       Successfully uninstalled click-8.1.7
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.20.1
#     Uninstalling pydantic_core-2.20.1:
#       Successfully uninstalled pydantic_core-2.20.1
#   Attempting uninstall: typer
#     Found existing installation: typer 0.9.0
#     Uninstalling typer-0.9.0:
#       Successfully uninstalled typer-0.9.0
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.8.2
#     Uninstalling pydantic-2.8.2:
#       Successfully uninstalled pydantic-2.8.2
# Successfully installed annotated-doc-0.0.4 brotli-1.2.0 click-8.4.1 fastapi-0.136.3 gradio-6.15.2 gradio-client-2.5.0 groovy-0.1.2 hf-gradio-0.4.1 hf-xet-1.5.0 huggingface-hub-1.17.0 orjson-3.11.9 pydantic-2.13.4 pydantic-core-2.46.4 pydub-0.25.1 python-multipart-0.0.30 safehttpx-0.1.7 semantic-version-2.10.0 starlette-1.2.1 tomlkit-0.14.0 typer-0.25.1 typing-extensions-4.15.0 typing-inspection-0.4.2 uvicorn-0.48.0
# WARNING: Ignoring invalid distribution ~lotly (C:\Users\mfrat\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~lotly (C:\Users\mfrat\anaconda3\Lib\site-packages)
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\mfrat\AppData\Local\Temp\pip-uninstall-bzkn9cea'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\mfrat\anaconda3\Lib\site-packages\~ydantic_core'.
#   You can safely remove it manually.
# WARNING: Ignoring invalid distribution ~lotly (C:\Users\mfrat\anaconda3\Lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# streamlit 1.37.1 requires packaging<25,>=20, but you have packaging 25.0 which is incompatible.

# %%
#Put here all the imports needed
import gradio as gr
